# %% [markdown]
# <a href="https://colab.research.google.com/github/Odilon01/7dayofcode/blob/main/C%C3%B3pia_de_7dayofcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *7 dias de Desafio Alura - Dados da Biblioteca da UFRN**
# ###### Primeiro dia - Importa os dados de Empréstimo dos Acervos do Sistema da Bibliotecas da UFRN
# ### **Solicitações do Cliente:**
# #### A Quantidade dos Emprestimos estâo Aumentanto ou Diminuindo ao decorrer dos  últimos anos?
# #####Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?
# #####Quais são os temas mais emprestados? E os menos?

# %% [markdown]
# ## Primeiro dia:

# %%
import pandas as pd
import pyarrow.parquet as pq
import numpy as np
import calendar

# %% [markdown]
# # Nova seção

# %%
#importando base direto do diretorio do GITHU

df101= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv', encoding='utf-8')
df102= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv', encoding='utf-8')
df111= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv', encoding='utf-8')
df112= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv', encoding='utf-8')
df121= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv', encoding='utf-8')
df122= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv', encoding='utf-8')
df131= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv', encoding='utf-8')
df132= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv', encoding='utf-8')
df141= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv', encoding='utf-8')
df142= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv', encoding='utf-8')
df151= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv', encoding='utf-8')
df152= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv', encoding='utf-8')
df161= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv', encoding='utf-8')
df162= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv', encoding='utf-8')
df171= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv', encoding='utf-8')
df172= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv', encoding='utf-8')
df181= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv', encoding='utf-8')
df182= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv', encoding='utf-8')
df191= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv', encoding='utf-8')
df192= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv', encoding='utf-8')
df201= pd.read_csv('https://raw.githubusercontent.com/Odilon01/7_Dias_de_C-digo_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv', encoding='utf-8')

# %%
#concatenando as planilhas em um único arquivo
dados_emprestimos = pd.concat([df101, df102, df111, df112,df121, df122, df131, df132, df141,df142, df151,df152,df161,df162,df171,df172,df181,df182,df191,df192,df201],ignore_index =True)

# %%
dados_emprestimos.head(10)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
# 5         709685       L167050                            NaN
# 6         709686    2006017618  2010/01/26 08:07:01.738000000
# 7         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
# 9         709689       L157395  2010/01/19 15:59:26.447000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# ...

# %%
#importar dados Exemplares
dados_exemplares = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/Curso Estatística Python/Dados/7dayofcode/dados_exemplares.parquet')

# %%
dados_exemplares.head(10)
# Out:
#        id_exemplar                codigo_barras            colecao  \
# index
# 0                5                      L000003  Acervo Circulante
# 1                4                      L000002  Acervo Circulante
# 2                3                      L000001  Acervo Circulante
# 3                7                      L000114  Acervo Circulante
# 5               10                      L000041  Acervo Circulante
# 7               13                      L000924       Dissertações
# 8               12                      L000056       Dissertações
# 12              19  L116810_23/09/2020 00:01:33  Acervo Circulante
# 13              20                      L000088  Acervo Circulante
# 14              21                      L117745  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# ...

# %%
#informação sobre os dados
dados_emprestimos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2258018 entries, 0 to 2258017
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 120.6+ MB

# %%
#verificar as informações dos dados
dados_emprestimos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2258018 entries, 0 to 2258017
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 120.6+ MB

# %%
dados_emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %%
#Eliminando dados duplicados dos datafreme emprestimos
emprestimos_sem_duplicadas = dados_emprestimos.drop_duplicates()

# %%
emprestimos_sem_duplicadas.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# ...

# %%
#unificando os dois dataframes com o merge

dados_completos_biblioteca = emprestimos_sem_duplicadas.merge(dados_exemplares)
dados_completos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
from pandas.core.groupby import groupby
#criando um grupo das Bibliotecas para analise de quantidades maximas e minimas de aluguel
grupo_bibliotecas = dados_completos_biblioteca.groupby('biblioteca')

# %%
grupo_bibliotecas.id_emprestimo.describe().round(2)
# Out:
#                                                         count        mean  \
# biblioteca
# Biblioteca Central Zila Mamede                      1426122.0  1858890.45
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...    46040.0  1764364.25
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...    32097.0  2470691.90
# Biblioteca Setorial Moacyr de Góes - CE                1036.0  1962186.24
# Biblioteca Setorial Pe. Jaime Diniz - Escola de...    21476.0  1866994.99
# Biblioteca Setorial Prof. Alberto Moreira Campo...    66447.0  1913561.97
# Biblioteca Setorial Prof. Dr. Marcelo Bezerra d...     5057.0  1786311.93
# Biblioteca Setorial Prof. Francisco Gurgel De A...    26923.0  1804127.50
# Biblioteca Setorial Prof. Horácio Nicolas Solim...     4098.0  1666317.10
# Biblioteca Setorial Prof. Leopoldo Nelson - ­Ce...    12900.0  2458759.41
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...    27219.0  2212753.41
# ...

# %% [markdown]
# # **Segundo dia:**
#
#  Manipular os dados;
#
#  Realizar limpeza dos dados;
#
# # **Solicitção do Cliente:**
#
# 1- Classificar a coluna localização de acordo com a classificação CDU.
#
# 2- Excluir a  Coluna Registro_Sistema .
#
# 3- A Coluna "matricula_ou_siape" não esta legível, melhorar a visualização e formato transformando em String.

# %%
#Excluindo a coluna registro_sistema. Atividade 02
dados_completos_biblioteca = dados_completos_biblioteca.drop('registro_sistema', axis = 1)

# %%
#Verificando a as informações do Dataframe e confirmando a exclução da coluna "registro_sistema"
dados_completos_biblioteca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2072522 entries, 0 to 2072521
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 205.6+ MB

# %%
# Atividade 03 - A Coluna "matricula_ou_siape" não esta legível, melhorar a visualização. Transformar em String.
dados_completos_biblioteca.matricula_ou_siape.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2072522 entries, 0 to 2072521
# Series name: matricula_ou_siape
# Non-Null Count    Dtype
# --------------    -----
# 2069629 non-null  float64
# dtypes: float64(1)
# memory usage: 31.6 MB

# %% [markdown]
# > Bloco com recuo

# %%
dados_completos_biblioteca.matricula_ou_siape
# Out:
# 0          2.008023e+09
# 1          2.009122e+09
# 2          2.008023e+09
# 3          2.008050e+09
# 4          2.007226e+08
#                ...
# 2072517    2.015011e+10
# 2072518    2.019004e+10
# 2072519    2.019102e+10
# 2072520    2.015013e+10
# 2072521    2.020001e+10
# Name: matricula_ou_siape, Length: 2072522, dtype: float64

# %%
#Convertendo a coluna matricula_ou_siape em String - astype(str)
dados_completos_biblioteca['matricula_ou_siape'] = dados_completos_biblioteca['matricula_ou_siape'].astype(str)

# %%
dados_completos_biblioteca.matricula_ou_siape
# Out:
# 0           2008023265.0
# 1           2009121584.0
# 2           2008023265.0
# 3           2008050352.0
# 4            200722565.0
#                ...
# 2072517    20150109837.0
# 2072518    20190035012.0
# 2072519    20191021693.0
# 2072520    20150129867.0
# 2072521    20200005327.0
# Name: matricula_ou_siape, Length: 2072522, dtype: object

# %%
dados_completos_biblioteca.localizacao
# Out:
# 0          630
# 1          630
# 2          647
# 3          647
# 4          647
#           ...
# 2072517    676
# 2072518    228
# 2072519    784
# 2072520    663
# 2072521    355
# Name: localizacao, Length: 2072522, dtype: int64

# %%
#Atividade 01 - Classificar a coluna localização de acordo com a classificação CDU.

CDU_lista = []
for CDU in dados_completos_biblioteca['localizacao']:
  if (CDU <100):
    CDU_lista.append('Generalidades')
  elif (CDU <200):
    CDU_lista.append('Filosifia. psicologia')
  elif (CDU <300):
    CDU_lista.append('Religião')
  elif (CDU <400):
    CDU_lista.append('Ciência sociais')
  elif (CDU <500):
    CDU_lista.append('Classe Vaga')
  elif (CDU <600):
    CDU_lista.append('Ciência sociais')
  elif (CDU <700):
    CDU_lista.append('Belas artes')
  elif (CDU <800):
    CDU_lista.append('Linguagem')
  else:
    CDU_lista.append('Geografia')

dados_completos_biblioteca['CD_Geral'] = CDU_lista

# %%
#Homologando Alteração
dados_completos_biblioteca[dados_completos_biblioteca['localizacao']==999]
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 2006956        2572473    2017032869                            NaN
# 2006957        2679199    2017032869                            NaN
# 2006958        2700992    2017032869  2018/08/17 20:16:52.304000000
# 2006959        2724803    2017032869                            NaN
# 2006960        2751793    2017032869                            NaN
# ...                ...           ...                            ...
# 2068491        2946340    2019006497                            NaN
# 2068492        2947199    2019006497  2019/11/18 07:04:00.256000000
# 2068493        2966000    2019006497  2020/02/14 00:41:59.665000000
# 2068494        2989059    2019006497                            NaN
# 2070161        2954012    2018001728                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 2006956  2017/11/28 10:12:18.547000000  2017/11/30 07:16:41.000000000
# ...

# %%
pd.value_counts(CDU_lista)
# Out:
# Belas artes              1425473
# Ciência sociais           438280
# Generalidades              62521
# Religião                   62295
# Filosifia. psicologia      60563
# Geografia                  15479
# Linguagem                   7911
# dtype: int64

# %%
(dados_completos_biblioteca['CD_Geral'].value_counts(normalize = True)*100).round(2)
# Out:
# Belas artes              68.78
# Ciência sociais          21.15
# Generalidades             3.02
# Religião                  3.01
# Filosifia. psicologia     2.92
# Geografia                 0.75
# Linguagem                 0.38
# Name: CD_Geral, dtype: float64

# %%
frenquencia_CDU = (dados_completos_biblioteca['CD_Geral']).value_counts().round(2)
percentual_CDU = (dados_completos_biblioteca['CD_Geral'].value_counts(normalize=True)*100).round(2)
dist_freq_CDU = pd.DataFrame({'Frequencia': frenquencia_CDU, 'Porcentagem (%)': percentual_CDU})
dist_freq_CDU.rename_axis('CDU', axis='columns', inplace=True)
dist_freq_CDU
# Out:
# CDU                    Frequencia  Porcentagem (%)
# Belas artes               1425473            68.78
# Ciência sociais            438280            21.15
# Generalidades               62521             3.02
# Religião                    62295             3.01
# Filosifia. psicologia       60563             2.92
# Geografia                   15479             0.75
# Linguagem                    7911             0.38

# %%
#Trabalhando com grafico
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.rc('figure', figsize = (20,10))
#fig =grupo_bibliotecas['id_emprestimo'].mean().plot.bar(color = 'blue')
#fig.set_ylabel('Quantidade')
#fig.set_title('Quantidade de Livros Alugados por Biblioteca',{'fontsize':22})

# %% [markdown]
# # Terceiro dia
#
# O Cliente solicitou as seguintes analises:
#
# Visualização da quantidade de totais de emprestimos por ano. Obs: Exemplares emprestados, e não de empréstimos realizados.
#
# O Cliente gostaria de visualizar os meses com a menor demanda de emprestimos. Com essas visualização ele vai conseguir tomar a desição de alocação de recursoss humanos. Existe uma sentimento que os meses de Março e Semtebro são os maiores.
#
# O Cliente gostaria de visualizar os dados em um grafico em Barra para os meses com o maiores fluxos de emprestimos.

# %%
dados_completos_biblioteca.head(2)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/03/01 12:40:56.212000000  2010/04/30 14:42:35.366000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2009121584.0  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
#
#                        biblioteca status_material  localizacao     CD_Geral
# 0  Biblioteca Central Zila Mamede         REGULAR          630  Belas artes
# 1  Biblioteca Central Zila Mamede         REGULAR          630  Belas artes

# %%
#Novo DataFreme para analise e manipulação dos Dados para demanda do dia 03
analise_emprestimos = dados_completos_biblioteca

# %%
dados_emprestimos.head(2)
# Out:
#    id_emprestimo codigo_barras data_renovacao                data_emprestimo  \
# 0         709684       L095049            NaN  2010/01/04 07:44:10.721000000
# 1         709685       L167050            NaN  2010/01/04 07:44:10.750000000
#
#                   data_devolucao  matricula_ou_siape tipo_vinculo_usuario
# 0  2010/01/05 16:26:12.662000000        2.008023e+09   ALUNO DE GRADUAÇÃO
# 1  2010/01/12 07:34:13.934000000        2.008023e+09   ALUNO DE GRADUAÇÃO

# %%
#Converte datas para analise de emprestimos x Ano
analise_emprestimos['data_emprestimo'] = pd.to_datetime(analise_emprestimos['data_emprestimo'])
analise_emprestimos['data_renovacao'] = pd.to_datetime(analise_emprestimos['data_renovacao'])
analise_emprestimos['data_devolucao'] = pd.to_datetime(analise_emprestimos['data_devolucao'])

# %%
#Adicionando uma coluna chamada Ano para analise dos emprestimos por ano
analise_emprestimos['Ano'] = analise_emprestimos['data_emprestimo'].dt.year

# %%
#Agrupanos os dados pela coluna ano
emprestimos_ano = analise_emprestimos.groupby('Ano')['id_emprestimo'].count()

# %%
#Ordenar emprestimos do maior para menor
emprestimos_ano = emprestimos_ano.sort_values(ascending=False)
emprestimos_ano
# Out:
# Ano
# 2013    234749
# 2012    221365
# 2014    219189
# 2017    218462
# 2016    215900
# 2015    213582
# 2011    196390
# 2018    194080
# 2019    171801
# 2010    161394
# 2020     25610
# Name: id_emprestimo, dtype: int64

# %%
emprestimos_ano = emprestimos_ano.rename("Quantidade")
emprestimos_ano
# Out:
# Ano
# 2013    234749
# 2012    221365
# 2014    219189
# 2017    218462
# 2016    215900
# 2015    213582
# 2011    196390
# 2018    194080
# 2019    171801
# 2010    161394
# 2020     25610
# Name: Quantidade, dtype: int64

# %%
#Trabalhando com grafico
# %matplotlib inline
import matplotlib.pyplot as plt

#criando grafico por barra
emprestimos_ano.plot(kind='bar')
#Definir os rotulos do eixo x e y
plt.xlabel('Ano')
plt.ylabel('Quantidade de Empréstimos')
#definir o titulo para o grafico
plt.title('Quantidade de Empréstimos por Ano')
#exibir o grafico
plt.show()

# %%
#Dia 03 - Analise dos mêses com o maior quantidade de emprestimos
#Adicionando uma coluna mês 'dt.month'
analise_emprestimos['Mes'] = analise_emprestimos['data_emprestimo'].dt.month

# %%
#Adicionando um grupo para analisar a quantidade por Mês e ordenar pelos maior valores
emprestimos_mes = analise_emprestimos.groupby('Mes')['id_emprestimo'].count()
emprestimos_mes = emprestimos_mes.sort_values(ascending=False)
emprestimos_mes
# Out:
# Mes
# 3     252185
# 8     232793
# 2     210200
# 4     208725
# 9     208234
# 5     202530
# 10    188410
# 11    164222
# 6     138123
# 7     123790
# 12     75796
# 1      67514
# Name: id_emprestimo, dtype: int64

# %%
#Renomendo os números dos meses para o nome

emprestimos_mes = emprestimos_mes.rename(index=calendar.month_name)
emprestimos_mes
# Out:
# Mes
# 3     252185
# 8     232793
# 2     210200
# 4     208725
# 9     208234
# 5     202530
# 10    188410
# 11    164222
# 6     138123
# 7     123790
# 12     75796
# 1      67514
# Name: (, January, February, March, April, May, June, July, August, September, October, November, December), dtype: int64

# %%
#Adicionando Grafico dos emprestimos por mês
ax = emprestimos_mes.plot(kind='bar')
#definir os rotulos para x e y
ax.set_xlabel('Mês')
ax.set_ylabel('Quantidade de Empréstimos')
#definir o título
ax.set_title('Maior quantidade de Empréstimos por Mês')
#incluindo os nomes dos meses no grafico
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
#exibir o grafico
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Quarto dia:
#
# Solicitação do Cliente:
#
# 1 - Como se distribuem os empréstimos de exemplares pelo tipos de vínculos dos usuários. Objetivo: Entnder qual é o público que está utilizando a Biblioteca
#
# 2- Quais coleções são mais emprestadas?
#
# 3- Quais são as Bibliotecas com mais ou menos quantidade de empréstimos?

# %%
#Porcentagem dos tipos de usuário por quantidade de emprestimos

frequencia_tipo_usuario = analise_emprestimos.groupby('tipo_vinculo_usuario')['id_emprestimo'].count().round(2)
frequencia_tipo_usuario = frequencia_tipo_usuario.sort_values(ascending=False)
percentual_user_tipo = (dados_completos_biblioteca['tipo_vinculo_usuario'].value_counts(normalize=True)*100).round(2)
dist_freq_user =pd.DataFrame({ 'Quantidade':frequencia_tipo_usuario, 'Porcentagem (%)': percentual_user_tipo }).round(2)
dist_freq_user.rename_axis('Classificação Usuário', axis='columns',inplace=True)
dist_freq_user
# Out:
# Classificação Usuário            Quantidade  Porcentagem (%)
# ALUNO DE GRADUAÇÃO                  1612324            77.80
# ALUNO DE PÓS-GRADUAÇÃO               302541            14.60
# DOCENTE                               70981             3.42
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184             1.55
# ALUNO MÉDIO/TÉCNICO                   28029             1.35
# DOCENTE EXTERNO                       23949             1.16
# USUÁRIO EXTERNO                        2509             0.12
# OUTROS                                    5             0.00

# %%
# Item 2- Quais coleções são mais emprestadas?
dados_completos_biblioteca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2072522 entries, 0 to 2072521
# Data columns (total 15 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        datetime64[ns]
#  3   data_emprestimo       datetime64[ns]
#  4   data_devolucao        datetime64[ns]
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  CD_Geral              object
#  13  Ano                   int64
#  14  Mes                   int64
# dtypes: datetime64[ns](3), int64(5), object(7)
# memory usage: 253.0+ MB

# %%
dados_completos_biblioteca.colecao
# Out:
# 0          Acervo Circulante
# 1          Acervo Circulante
# 2          Acervo Circulante
# 3          Acervo Circulante
# 4          Acervo Circulante
#                  ...
# 2072517    Acervo Circulante
# 2072518    Acervo Circulante
# 2072519    Acervo Circulante
# 2072520    Acervo Circulante
# 2072521    Acervo Circulante
# Name: colecao, Length: 2072522, dtype: object

# %%
#Porcentagem do tipo de Coleção por Emprestimo

frequencia_colecao = analise_emprestimos.groupby('colecao')['id_emprestimo'].count().round(2)
frequencia_colecao = frequencia_colecao.sort_values(ascending=False)
percentual_colecao_tipo= (dados_completos_biblioteca['colecao'].value_counts(normalize=True)*100).round(2)
dist_freq_colecao =pd.DataFrame({'Quantidade':frequencia_colecao,'Porcentagem (%)': percentual_colecao_tipo }).round(2)
dist_freq_colecao.rename_axis('Coleção', axis='columns',inplace=True)
dist_freq_colecao
# Out:
# Coleção                                Quantidade  Porcentagem (%)
# Acervo Circulante                         2053120            99.06
# Multimeios                                   7954             0.38
# Monografias                                  4021             0.19
# Dissertações                                 2406             0.12
# Obras de Referência                          1954             0.09
# Publicações de Autores do RN                  866             0.04
# Publicações da UFRN                           764             0.04
# Teses                                         714             0.03
# Folhetos                                      271             0.01
# Necessidades Educacionais Específicas         130             0.01
# Trabalho Acadêmico                            115             0.01
# Eventos                                       101             0.00
# Coleção Mossoroense                            44             0.00
# ...

# %%
#Porcentagem de Bibliotecas com maior volume de Emprestimos
frenquencia_biblioteca = (dados_completos_biblioteca['biblioteca']).value_counts().round(2)
percentual_biblioteca = (dados_completos_biblioteca['biblioteca'].value_counts(normalize=True)*100).round(2)
dist_freq_biblioteca = pd.DataFrame({'Frequência': frenquencia_biblioteca, 'Porcentagem (%)': percentual_biblioteca}).round(2)
dist_freq_biblioteca.rename_axis('Biblioteca', axis='columns', inplace=True)
dist_freq_biblioteca
# Out:
# Biblioteca                                          Frequência  \
# Biblioteca Central Zila Mamede                         1426122
# Biblioteca Setorial do Centro Ciências da Saúde...      118614
# Biblioteca Setorial da Faculdade de Ciências da...       77609
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040
# Biblioteca Setorial do Centro de Ciências Human...       40744
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923
# Biblioteca Setorial do Núcleo de Educação da In...       23656
# Biblioteca Setorial Prof. Ronaldo Xavier de Arr...       22749
# Biblioteca Setorial Pe. Jaime Diniz - Escola de...       21476
# ...

# %%
#Porcentagem de CDU por emprestimos
frenquencia_CDU = (dados_completos_biblioteca['CD_Geral']).value_counts().round(2)
percentual_CDU = (dados_completos_biblioteca['CD_Geral'].value_counts(normalize=True)*100).round(2)
dist_freq_CDU = pd.DataFrame({'Frequência': frenquencia_CDU, 'Porcentagem (%)': percentual_CDU}).round(2)
dist_freq_CDU.rename_axis('CDU', axis='columns', inplace=True)
dist_freq_CDU
# Out:
# CDU                    Frequência  Porcentagem (%)
# Belas artes               1425473            68.78
# Ciência sociais            438280            21.15
# Generalidades               62521             3.02
# Religião                    62295             3.01
# Filosifia. psicologia       60563             2.92
# Geografia                   15479             0.75
# Linguagem                    7911             0.38

# %% [markdown]
# #Quinto dia:
#
#  Boxplot
#
# 1 - Veririfcar qual é a coleção com maior frequência para cada tipo de usuário
#
# 2 - Selecionar apenas os empréstimos
#
# 3 - Criar uma função para gerar a visualização do grafico de box plot por cada ano.
#
# 4- Crie o gráfico de boxplot.

# %%
#Detalhar a maior frequencia de Alunos e Coleção (Alunos de Gradução e Acervo Circulante)
import seaborn as sns

# %%
dados_completos_biblioteca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2072522 entries, 0 to 2072521
# Data columns (total 15 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        datetime64[ns]
#  3   data_emprestimo       datetime64[ns]
#  4   data_devolucao        datetime64[ns]
#  5   matricula_ou_siape    object
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  CD_Geral              object
#  13  Ano                   int64
#  14  Mes                   int64
# dtypes: datetime64[ns](3), int64(5), object(7)
# memory usage: 253.0+ MB

# %%
alunos_graduacao = dados_completos_biblioteca.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: colecao, dtype: int64

# %%
#Criando uma tabela com quantidade por ano
alunos_graduacao_acervo_circulante = alunos_graduacao.query('colecao == "Acervo Circulante"')
alunos_graduacao_acervo_circulante = pd.DataFrame(alunos_graduacao_acervo_circulante)
alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_graduacao_acervo_circulante['data_emprestimo'])
alunos_graduacao_acervo_circulante['ano'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_graduacao_acervo_circulante['mes'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %% [markdown]
# Criando o Box Plot

# %%
def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)
  plt.figure(figsize=(16,10))

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel(None)
  plt.ylabel(None)

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %% [markdown]
# Utilizando BOx Plot para distribuir os emprestimos mensais pelos Alunos

# %%
from matplotlib.widgets import ticker
gera_box_plot(alunos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos Anuais', 'Realizados pelos alunos de Pos Graduação')

# %%
gera_box_plot(alunos_graduacao_acervo_circulante,'mes','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de Pos Graduação')

# %% [markdown]
# #Sexto dia -
# Importa dados Excel e Json
#
# Extraia os dados destes aquivos, agrupe-os em apenas um só e verifique depois a quantidade de empréstimos.
#
# Gere um tabela com as seguintes características:
#
# Índice: Cursos
#
# Colunas: Ano
#
# Valores: Qunatidade de empréstimos
#
# Total: Acrescente uma linha e uma coluna de total a tabela
#
# Analisar as seguintes situações:
#
# 1 - Calcular a quantidade de empréstimos realizados entre 2015 e 2020 por cada curso que passará pelo um avaliação.
#
# Os Cursos São:
#
# Biblioteconomia
#
# Ciência sociais
#
# Comunicação social
#
# Direito
#
# Filosofia
#
# Pedagogia

# %%
#importando novos dados
cadastro_usuario_antes_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuario_depois_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)
cadastro_usuarios_json = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')

# %%
cadastro_usuario_antes_2010
# Out:
#       Número da matrícula     Tipo de vinculo  \
# 0            1.900017e+08  ALUNO DE GRADUAÇÃO
# 1            1.990145e+08  ALUNO DE GRADUAÇÃO
# 2            1.997357e+08  ALUNO DE GRADUAÇÃO
# 3            1.998124e+08  ALUNO DE GRADUAÇÃO
# 4            1.998237e+08  ALUNO DE GRADUAÇÃO
# ...                   ...                 ...
# 7721         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7722         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7723         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7724         2.009075e+09  ALUNO DE GRADUAÇÃO
# 7725         2.009075e+09  ALUNO DE GRADUAÇÃO
#
#                                       Curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %%
cadastro_usuario_antes_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso'] #renomenado as colunas
cadastro_usuario_antes_2010
# Out:
#       matricula_ou_siape tipo_vinculo_usuario  \
# 0           1.900017e+08   ALUNO DE GRADUAÇÃO
# 1           1.990145e+08   ALUNO DE GRADUAÇÃO
# 2           1.997357e+08   ALUNO DE GRADUAÇÃO
# 3           1.998124e+08   ALUNO DE GRADUAÇÃO
# 4           1.998237e+08   ALUNO DE GRADUAÇÃO
# ...                  ...                  ...
# 7721        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7722        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7723        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7724        2.009075e+09   ALUNO DE GRADUAÇÃO
# 7725        2.009075e+09   ALUNO DE GRADUAÇÃO
#
#                                       curso
# 0                                MATEMÁTICA
# 1                       CIÊNCIAS BIOLÓGICAS
# 2                                MATEMÁTICA
# 3                                    LETRAS
# 4                                  ECOLOGIA
# ...                                     ...
# 7721                        BIBLIOTECONOMIA
# 7722  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS
# ...

# %%
cadastro_usuario_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso'] #renomeando as colunas
cadastro_usuario_depois_2010
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           2.010000e+09   ALUNO DE GRADUAÇÃO                   DIREITO
# 1           2.010000e+09   ALUNO DE GRADUAÇÃO                 AGRONOMIA
# 2           2.010001e+09   ALUNO DE GRADUAÇÃO        ENGENHARIA QUÍMICA
# 3           2.010003e+09   ALUNO DE GRADUAÇÃO      ENGENHARIA AMBIENTAL
# 4           2.010003e+09   ALUNO DE GRADUAÇÃO                 GEOGRAFIA
# ...                  ...                  ...                       ...
# 2269        2.015012e+10   ALUNO DE GRADUAÇÃO                    LETRAS
# 2270        2.015075e+09   ALUNO DE GRADUAÇÃO                     DANÇA
# 2271        2.016000e+10   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 2272        2.017009e+10   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 2273        2.018009e+10   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [2274 rows x 3 columns]

# %%
cadastro_usuarios_jso
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
from tables import index
#Concatenando os arquivos em Excel
cadastro_usuarios_excel = pd.concat([cadastro_usuario_antes_2010, cadastro_usuario_depois_2010],ignore_index=True)
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string') #converte a coluna para string
cadastro_usuarios_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %%
#Arquivo JSON
cadastro_usuarios_graduacao_json = pd.read_json(cadastro_usuarios_json.registros[0])
cadastro_usuarios_graduacao_json
# Out:
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799         20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800         20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801         20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %%
#Verificar os dados do arquivo JSON

cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  int64
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
#converter a coluna matricula ou siape para String
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  string
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: object(2), string(1)
# memory usage: 1.4+ MB

# %%
#concatenando os arquivos Excel e Jons
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel, cadastro_usuarios_graduacao_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                 curso
# 0            190001688.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1            199014489.0   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2            199735674.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3            199812431.0   ALUNO DE GRADUAÇÃO                LETRAS
# 4            199823670.0   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                  ...                  ...                   ...
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798      20200039601.0   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799      20200132517.0   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]
# ...

# %%
#Empréstimos de Alunos de 2015 em diante
#Vamos utilizar duas fontes de dados
matricula_data_de_emprestimos = dados_completos_biblioteca.query("tipo_vinculo_usuario == 'ALUNO DE GRADUAÇÃO'")
matricula_data_de_emprestimos = matricula_data_de_emprestimos.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimos = matricula_data_de_emprestimos.query('data_emprestimo > 2015')
matricula_data_de_emprestimos = matricula_data_de_emprestimos.reset_index(drop=True)
matricula_data_de_emprestimos
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2014083920.0 2015-02-03 14:56:17.005
# 1            2014083949.0 2015-03-06 13:16:57.907
# 2            2014083920.0 2015-04-06 16:58:10.691
# 3            2014083920.0 2015-05-27 17:39:48.592
# 4            2014084089.0 2015-07-28 17:46:49.875
# ...                   ...                     ...
# 788099      20160144295.0 2020-03-17 18:33:29.752
# 788100      20150109837.0 2020-03-17 19:49:10.187
# 788101      20190035012.0 2020-03-17 19:51:15.700
# 788102      20150129867.0 2020-03-17 20:47:18.741
# 788103      20200005327.0 2020-03-17 21:22:22.138
#
# [788104 rows x 2 columns]

# %%
#Excluindo dados Nullos
matricula_data_de_emprestimos.isna().sum()
# Out:
# matricula_ou_siape    0
# data_emprestimo       0
# dtype: int64

# %%
matricula_data_de_emprestimos = matricula_data_de_emprestimos.dropna()

# %%
#Filtrando os cursos selecionados
cadastro_usuarios_cursos_selecionados = cadastro_usuarios_cursos.query("curso == ['BIBLIOTECONOMIA','CIÊNCIAS BIOLÓGICAS','COMUNICAÇÃO SOCIAL','DIREITO','FILOSOFIA','PEDAGOGIA']")
cadastro_usuarios_cursos_selecionados
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                curso
# 1            199014489.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 8            200031011.0   ALUNO DE GRADUAÇÃO              DIREITO
# 9            200045080.0   ALUNO DE GRADUAÇÃO      BIBLIOTECONOMIA
# 18           200123382.0   ALUNO DE GRADUAÇÃO      BIBLIOTECONOMIA
# 19           200123730.0   ALUNO DE GRADUAÇÃO      BIBLIOTECONOMIA
# ...                  ...                  ...                  ...
# 72789      20200097481.0   ALUNO DE GRADUAÇÃO            PEDAGOGIA
# 72796      20200107087.0   ALUNO DE GRADUAÇÃO            PEDAGOGIA
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO      BIBLIOTECONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO      BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO              DIREITO
#
# [18860 rows x 3 columns]

# %%
#Unir os Dataframes Cadastro de usuários selecionados com o de Data de Emprestimos
cadastro_usuarios_cursos_selecionados = matricula_data_de_emprestimos.merge(cadastro_usuarios_cursos_selecionados)
cadastro_usuarios_cursos_selecionados
# Out:
#        matricula_ou_siape         data_emprestimo tipo_vinculo_usuario  \
# 0           20180154181.0 2018-09-18 20:07:53.876   ALUNO DE GRADUAÇÃO
# 1           20180154181.0 2020-03-04 16:17:32.383   ALUNO DE GRADUAÇÃO
# 2           20180154181.0 2018-12-07 19:00:16.733   ALUNO DE GRADUAÇÃO
# 3           20180154181.0 2018-08-21 19:39:07.928   ALUNO DE GRADUAÇÃO
# 4           20180154181.0 2018-09-28 18:38:58.259   ALUNO DE GRADUAÇÃO
# ...                   ...                     ...                  ...
# 212531      20200007626.0 2020-03-07 13:12:56.894   ALUNO DE GRADUAÇÃO
# 212532      20200007626.0 2020-03-07 13:12:56.956   ALUNO DE GRADUAÇÃO
# 212533      20200102920.0 2020-03-09 18:47:56.608   ALUNO DE GRADUAÇÃO
# 212534      20190121101.0 2020-03-13 09:08:44.544   ALUNO DE GRADUAÇÃO
# 212535      20200144278.0 2020-03-13 09:16:50.082   ALUNO DE GRADUAÇÃO
#
#                       curso
# 0           BIBLIOTECONOMIA
# 1           BIBLIOTECONOMIA
# ...

# %%
#transformar a coluna data_emprestimo em Ano
cadastro_usuarios_cursos_selecionados.data_emprestimo = cadastro_usuarios_cursos_selecionados.data_emprestimo.dt.year

# %%
#Criando um coluna quantidade de cursos por ano


emprestimos_cursos_selecionados = cadastro_usuarios_cursos_selecionados.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_cursos_selecionados.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_cursos_selecionados
# Out:
#      ANO                CURSO  QUANTIDADE_EMPRESTIMOS
# 0   2017   COMUNICAÇÃO SOCIAL                    8253
# 1   2016   COMUNICAÇÃO SOCIAL                    7973
# 2   2017              DIREITO                    7885
# 3   2015      BIBLIOTECONOMIA                    7784
# 4   2015              DIREITO                    7665
# 5   2016            FILOSOFIA                    7576
# 6   2017            PEDAGOGIA                    7434
# 7   2017            FILOSOFIA                    7389
# 8   2016              DIREITO                    7363
# 9   2017      BIBLIOTECONOMIA                    7307
# 10  2017  CIÊNCIAS BIOLÓGICAS                    7253
# 11  2015            PEDAGOGIA                    7189
# 12  2016            PEDAGOGIA                    7153
# 13  2015   COMUNICAÇÃO SOCIAL                    7147
# 14  2016      BIBLIOTECONOMIA                    7044
# 15  2018              DIREITO                    7027
# ...

# %% [markdown]
# T

# %% [markdown]
# Tabela Pivotada com as Colunas Slicitadas
#
# Índice: Cursos
#
# Colunas: Ano
#
# Valores: Qunatidade de empréstimos
#
# Total: Acrescente uma linha e uma coluna de total a tabela

# %%
emprestimos_cursos_selecionados_pivot = emprestimos_cursos_selecionados.pivot_table(
    index = 'CURSO',
    columns = 'ANO',
    values = 'QUANTIDADE_EMPRESTIMOS',
    fill_value = '-',
    aggfunc = sum,
    margins = True,
    margins_name = 'TOTAL',
)
emprestimos_cursos_selecionados_pivot
# Out:
# ANO                   2015   2016   2017   2018   2019  2020   TOTAL
# CURSO
# BIBLIOTECONOMIA       7784   7044   7307   6378   5889   900   35302
# CIÊNCIAS BIOLÓGICAS   6930   6994   7253   6524   5344   832   33877
# COMUNICAÇÃO SOCIAL    7147   7973   8253   6953   5885   796   37007
# DIREITO               7665   7363   7885   7027   5861   905   36706
# FILOSOFIA             6950   7576   7389   6296   5572   832   34615
# PEDAGOGIA             7189   7153   7434   6518   5869   866   35029
# TOTAL                43665  44103  45521  39696  34420  5131  212536

# %% [markdown]
# ## Setimo dia:
